# %% [markdown]
# <h1>TP Apprentissage Non Supervisé</h1>

# %% [markdown]
# `WARNING : Il est conseillé au lancement de ce TP de lancer toutes les cellules d'un coup pour ne pas avoir des risques d'altération des valeurs.`

# %% [markdown]
# ### 1. Jeux de données

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn import cluster
from scipy.io import arff
from sklearn import metrics
import kmedoids
import scipy . cluster . hierarchy as shc
from sklearn.metrics.pairwise import euclidean_distances, manhattan_distances
import hdbscan
import pandas as pd 

path = './clustering-benchmark-master/src/main/resources/datasets/artificial/'

# %%
#Parser un fichier de donnees au format arff

databrut = arff.loadarff(open(path+"xclara.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ### 2. Clustering k-Means et k-Medoids

# %% [markdown]
# #### 2.1 Pour démarrer

# %%
def k_means(data,f0,f1,k,plot=False):
    print("Appel KMeans pour une valeur fixee de k")
    tps1 = time.time()
    model = cluster.KMeans(n_clusters=k, init='k-means++')
    model.fit(data)
    tps2 = time.time()
    labels = model.labels_
    iteration = model.n_iter_
    
    print("Coefficient de silhouette pour k =",k,":",metrics.silhouette_score(data,labels))
    print("Coefficient de Davies-Bouldin pour k =",k,":",metrics.davies_bouldin_score(data,labels))
    if(plot):
        plt.scatter(f0, f1, c=labels, s=8)
        plt.title("Donnees apres clustering Kmeans")
        plt.show()
    
    print("nv clusters =",k,", nb iter =", iteration,", ...... runtime = ", round((tps2-tps1)*1000,2),"ms\n")

print("DATA : \n")
    
for i in range(2,6):
    if(i == 3):
        k_means(data, f0,f1,i,True)
    else:
        k_means(data, f0,f1,i)
# Out:
# DATA :
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 2 : 0.542435069970526
# Coefficient de Davies-Bouldin pour k = 2 : 0.6777307283608246
# nv clusters = 2 , nb iter = 2 , ...... runtime =  1433.9 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 3 : 0.6945587736089913
# Coefficient de Davies-Bouldin pour k = 3 : 0.42056158508478453
# nv clusters = 3 , nb iter = 3 , ...... runtime =  1414.21 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 4 : 0.539112127422733
# Coefficient de Davies-Bouldin pour k = 4 : 0.8288077279104888
# nv clusters = 4 , nb iter = 7 , ...... runtime =  1605.88 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 5 : 0.4069616062077848
# Coefficient de Davies-Bouldin pour k = 5 : 1.0897509768746212
# nv clusters = 5 , nb iter = 10 , ...... runtime =  1461.94 ms

# %% [markdown]
# #### 2.2 Intérêts de la méthode k-Means  ( faire les questions )

# %%
# Set de certains jeux de données pour voir les effets de la méthodes k-means 

databrut2 = arff.loadarff(open(path+"shapes.arff",'r'))
databrut4 = arff.loadarff(open(path+"threenorm.arff",'r'))
databrut5 = arff.loadarff(open(path+"wingnut.arff",'r'))

print("\n\nDATA 2 : \n")
data2 = [[x[0],x[1]] for x in databrut2[0]]
f0 = [f[0] for f in data2]
f1 = [f[1] for f in data2]

for i in range(2,6):
    if(i == 2):
        k_means(data2, f0,f1,i,True)
    else:
        k_means(data2, f0,f1,i)

print("\n\nDATA 4 : \n")
data4 = [[x[0],x[1]] for x in databrut4[0]]
f0 = [f[0] for f in data4]
f1 = [f[1] for f in data4]

for i in range(2,6):
    if(i == 2):
        k_means(data4, f0,f1,i,True)
    else:
        k_means(data4, f0,f1,i)

print("\n\nDATA 5 : \n")
        
data5 = [[x[0],x[1]] for x in databrut5[0]]
f0 = [f[0] for f in data5]
f1 = [f[1] for f in data5]

for i in range(2,6):
    if(i == 2):
        k_means(data5, f0,f1,i,True)
    else:
        k_means(data5, f0,f1,i)
# Out:
# DATA 2 :
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 2 : 0.5305545278224536
# Coefficient de Davies-Bouldin pour k = 2 : 0.8553239680253826
# nv clusters = 2 , nb iter = 5 , ...... runtime =  1008.41 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 3 : 0.5868172229463942
# Coefficient de Davies-Bouldin pour k = 3 : 0.5812874556348132
# nv clusters = 3 , nb iter = 2 , ...... runtime =  1048.98 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 4 : 0.6945464131654676
# Coefficient de Davies-Bouldin pour k = 4 : 0.44368809096322703
# nv clusters = 4 , nb iter = 2 , ...... runtime =  1092.3 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 5 : 0.6558465241094414
# Coefficient de Davies-Bouldin pour k = 5 : 0.5384497519182669
# nv clusters = 5 , nb iter = 3 , ...... runtime =  1182.88 ms
#
#
#
# DATA 4 :
#
# Appel KMeans pour une valeur fixee de k
# ...

# %% [markdown]
# - Nous avons 4 jeux de données pour chacun la valeur du nombre de clusters est différentes :
#     * data : k = 3
#     * data2 : k = 4
#     * data4 : k = 3
#     * data5 : k = 2
#
# - les différentes valeurs de temps de calcul sont :
#     * data : 29.77 ms
#     * data2 : 33.09 ms
#     * data4 : 42.23 ms
#     * data5 : 20.25 ms
#
# - On ne connait pas le résultat attendu donc on ne peux pas comparer.

# %% [markdown]
# #### 2.3 Limites de la méthode k-Means

# %%
databrut3 = arff.loadarff(open(path+"spiral.arff",'r'))
data3 = [[x[0],x[1]] for x in databrut3[0]]
f0 = [f[0] for f in data3]
f1 = [f[1] for f in data3]

for i in range(2,6):
    k_means(data3,f0,f1,i)

databrut3 = arff.loadarff(open(path+"smile1.arff",'r'))
data3 = [[x[0],x[1]] for x in databrut3[0]]
f0 = [f[0] for f in data3]
f1 = [f[1] for f in data3]

for i in range(2,6):
    k_means(data3,f0,f1,i)
    
databrut3 = arff.loadarff(open(path+"smile2.arff",'r'))
data3 = [[x[0],x[1]] for x in databrut3[0]]
f0 = [f[0] for f in data3]
f1 = [f[1] for f in data3]

for i in range(2,6):
    k_means(data3,f0,f1,i)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 2 : 0.35386038956048077
# Coefficient de Davies-Bouldin pour k = 2 : 1.143839886856435
# nv clusters = 2 , nb iter = 22 , ...... runtime =  1668.25 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 3 : 0.3833181950872386
# Coefficient de Davies-Bouldin pour k = 3 : 0.8762861570252293
# nv clusters = 3 , nb iter = 7 , ...... runtime =  993.66 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 4 : 0.38958495939938187
# Coefficient de Davies-Bouldin pour k = 4 : 0.8012040356905097
# nv clusters = 4 , nb iter = 7 , ...... runtime =  1699.41 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 5 : 0.35805545250790793
# Coefficient de Davies-Bouldin pour k = 5 : 0.8404322962129147
# nv clusters = 5 , nb iter = 9 , ...... runtime =  1392.73 ms
#
# Appel KMeans pour une valeur fixee de k
# ...

# %%
databrut3 = arff.loadarff(open(path+"spiral.arff",'r'))
data3 = [[x[0],x[1]] for x in databrut3[0]]
f0 = [f[0] for f in data3]
f1 = [f[1] for f in data3]
k_means(data3,f0,f1,2, True)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 2 : 0.35386038956048077
# Coefficient de Davies-Bouldin pour k = 2 : 1.143839886856435
# nv clusters = 2 , nb iter = 23 , ...... runtime =  1577.25 ms

# %%
databrut3 = arff.loadarff(open(path+"smile1.arff",'r'))
data3 = [[x[0],x[1]] for x in databrut3[0]]
f0 = [f[0] for f in data3]
f1 = [f[1] for f in data3]


k_means(data3,f0,f1,4, True)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 4 : 0.6263115016259269
# Coefficient de Davies-Bouldin pour k = 4 : 0.6561809434785442
# nv clusters = 4 , nb iter = 4 , ...... runtime =  1728.51 ms

# %% [markdown]
# - le clustering pour les données qui ont été choisis est ambigüe. Il ne semble pas vraiment preter attention aux clusters et sépare les différentes données par tranches.

# %% [markdown]
# #### 2.4 Méthode k-medoids

# %%
def k_medoids(data,f0,f1, k, distance_function=euclidean_distances, plot=False):
    tps1 = time.time()
    distmatrix = distance_function(data)
    fp = kmedoids.fasterpam(distmatrix, k)
    tps2 = time.time()
    iter_kmed = fp.n_iter
    labels_kmed = fp.labels
    print('Loss with FasterPAM:', fp.loss)
    
    print("Coefficient de silhouette pour k =",k,":",metrics.silhouette_score(data,labels_kmed))
    print("Coefficient de Davies-Bouldin pour k =",k,":",metrics.davies_bouldin_score(data,labels_kmed))
    if(plot):
        plt.scatter(f0, f1, c=labels_kmed, s=8)
        plt.title("Donnees apres clustering Kmedoids")
        plt.show()
    print(" nb clusters =",k,", nb_iter =",iter_kmed,", ...... runtime =", round((tps2-tps1)*1000,2),"ms\n")

databrut = arff.loadarff(open(path+"xclara.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

for i in range(2,10):
    if(i==3): 
        k_medoids(data, f0,f1,i,plot=True)
    else:
        k_medoids(data, f0,f1,i)
# Out:
# Loss with FasterPAM: 73582.16599336648
# Coefficient de silhouette pour k = 2 : 0.5347384400282739
# Coefficient de Davies-Bouldin pour k = 2 : 0.6998468528573286
#  nb clusters = 2 , nb_iter = 3 , ...... runtime = 16713.0 ms
#
# Loss with FasterPAM: 38029.6560504377
# Coefficient de silhouette pour k = 3 : 0.6945587736089913
# Coefficient de Davies-Bouldin pour k = 3 : 0.42056158508478453
#  nb clusters = 3 , nb_iter = 2 , ...... runtime = 9312.19 ms
#
# Loss with FasterPAM: 35282.44112521062
# Coefficient de silhouette pour k = 4 : 0.5387488479142908
# Coefficient de Davies-Bouldin pour k = 4 : 0.829835032576368
#  nb clusters = 4 , nb_iter = 3 , ...... runtime = 16287.92 ms
#
# Loss with FasterPAM: 32853.46342351445
# Coefficient de silhouette pour k = 5 : 0.41083607048502896
# Coefficient de Davies-Bouldin pour k = 5 : 1.091471874616309
#  nb clusters = 5 , nb_iter = 2 , ...... runtime = 9607.98 ms
#
# Loss with FasterPAM: 30585.383148334953
# ...

# %% [markdown]
# - le bon nombre de clusters permettant d'obtenir un coefficient de silhouette proche de 1 est k = 3 pour cette même valeur nous avons un coefficient de Davies-Bouldin le plus faible signifiant un clustering qui est le plus optimisé.
# - Le temps de calcul pour une telle execution est 19,23 ms
# - Non, on ne connais pas le résultat attendu donc on ne peux pas comparer.

# %%
databrut = arff.loadarff(open(path+"smile1.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

for i in range(2,10):
    if(i==4): 
        k_medoids(data, f0,f1,i,plot=True)
    else:
        k_medoids(data, f0,f1,i)
# Out:
# Loss with FasterPAM: 217.46410699771891
# Coefficient de silhouette pour k = 2 : 0.4268393342124168
# Coefficient de Davies-Bouldin pour k = 2 : 1.1729800126293126
#  nb clusters = 2 , nb_iter = 2 , ...... runtime = 3585.61 ms
#
# Loss with FasterPAM: 115.4301848902654
# Coefficient de silhouette pour k = 3 : 0.6395785541456328
# Coefficient de Davies-Bouldin pour k = 3 : 0.5260935731024283
#  nb clusters = 3 , nb_iter = 2 , ...... runtime = 3305.04 ms
#
# Loss with FasterPAM: 94.76682539060326
# Coefficient de silhouette pour k = 4 : 0.6255591794338486
# Coefficient de Davies-Bouldin pour k = 4 : 0.6542468773996136
#  nb clusters = 4 , nb_iter = 2 , ...... runtime = 3396.34 ms
#
# Loss with FasterPAM: 84.96809227247957
# Coefficient de silhouette pour k = 5 : 0.6350491718894
# Coefficient de Davies-Bouldin pour k = 5 : 0.655544255745917
#  nb clusters = 5 , nb_iter = 4 , ...... runtime = 5757.98 ms
#
# Loss with FasterPAM: 77.7311788074814
# ...

# %%
def evaluation(data,f0,f1,k):
    
    # méthode K-means 
    model = cluster.KMeans(n_clusters=k, init='k-means++')
    model.fit(data)
    labels = model.labels_
    
    # méthode K-medoids
    distmatrix = euclidean_distances(data)
    fp = kmedoids.fasterpam(distmatrix, k)
    labels_kmed = fp.labels
    
    print("Similarity score of the data : \n\t- Rand_Score :",metrics.rand_score(labels,labels_kmed),"\n\t- Mutual_Info_Score :",metrics.mutual_info_score(labels,labels_kmed))

# %%
# Nous reprenons le premier dataset :

databrut = arff.loadarff(open(path+"xclara.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

evaluation(data,f0,f1,3)
# Out:
# Similarity score of the data :
# 	- Rand_Score : 1.0
# 	- Mutual_Info_Score : 1.0929325398637169

# %% [markdown]
# - Pour la valeur de k la plus pertinente dans les deux cas qui est 3 : Nous obtenons un rand_score de 1.0 qui traduit un perfect match et donc une répartition dans les différents clusters qui est la même. La valeur de mutual information, est de 1.09 légèrement différente qui peut se traduire par un échange entre certaines données des clusters.

# %%
# Pour le même dataset que précedemment nous allons prendre une valeur de k différente et nous allons
# faire varier la distance prise en compte. 

databrut = arff.loadarff(open(path+"xclara.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

k_medoids(data,f0,f1, 3)
k_medoids(data,f0,f1, 3, manhattan_distances)
# Out:
# Loss with FasterPAM: 38029.6560504377
# Coefficient de silhouette pour k = 3 : 0.6945587736089913
# Coefficient de Davies-Bouldin pour k = 3 : 0.42056158508478453
#  nb clusters = 3 , nb_iter = 2 , ...... runtime = 9949.48 ms
#
# Loss with FasterPAM: 48584.764578748
# Coefficient de silhouette pour k = 3 : 0.6943525902072846
# Coefficient de Davies-Bouldin pour k = 3 : 0.42002063697912134
#  nb clusters = 3 , nb_iter = 2 , ...... runtime = 9327.41 ms

# %% [markdown]
# - Au lieu d'utiliser la distance euclidienne nous avons opter pour la distance de manhattan on voit une légère dégradation au niveau du coefficient de silhouette pour un runtime qui est diminué de considérablement. Pour la faible diminution du coefficient de silhouette cela vaut le coup.

# %% [markdown]
# ### 3. Clustering agglomératif

# %% [markdown]
# #### 3.1 Pour démarrer

# %%
def print_dendrogramme(data):
    # Donnees dans datanp
    print (" Dendrogramme ’ single ’ donnees initiales")
    linked_mat = shc.linkage(data,'single')
    plt.figure(figsize = (12,12))
    shc.dendrogram(linked_mat,
    orientation = 'top',
    distance_sort = 'descending',
    show_leaf_counts = False)
    plt.show()
    

print_dendrogramme(data)
# Out:
#  Dendrogramme ’ single ’ donnees initiales

# %% [markdown]
# - code permettant de déterminer un clustering hiérarchique en utilisant soit une limite sur le seuil de distance soit un nombre de clusters.

# %%
def lim_cluster(data,kOrDist = True, distance=0.1, k=4):
    if kOrDist == True:
        # set distance_threshold ( 0 ensures we compute the full tree )
        tps1 = time.time()
        model = cluster.AgglomerativeClustering(distance_threshold = distance , linkage = 'single' , n_clusters = None)
        model = model.fit(data)
        tps2 = time.time()
        labels = model.labels_
        k = model.n_clusters_
        leaves = model.n_leaves_
        # Affichage clustering
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
        print("Coefficient de silhouette pour distance =",distance,":",metrics.silhouette_score(data,labels))
        print("Coefficient de Davies-Bouldin pour distance =",distance,":",metrics.davies_bouldin_score(data,labels))
        print(" nb clusters = ",k," , nb feuilles = ",leaves, " runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms\n" )

    if kOrDist == False:
        #set the number of clusters 
        tps1 = time.time()
        model = cluster.AgglomerativeClustering(linkage = 'single' , n_clusters = k)
        model = model.fit(data)
        tps2 = time.time()

        labels = model.labels_
        k = model.n_clusters_
        leaves = model.n_leaves_
        # Affichage clustering
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
        print("Coefficient de silhouette pour k =",k,":",metrics.silhouette_score(data,labels))
        print("Coefficient de Davies-Bouldin pour k =",k,":",metrics.davies_bouldin_score(data,labels))
        print(" nb clusters = ",k," , nb feuilles = ",leaves, " runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms\n" )
    
    
   
databrut = arff.loadarff(open(path+"smile1.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

# %%
lim_cluster(data)
# Out:
# Coefficient de silhouette pour distance = 0.1 : 0.5054942636304086
# Coefficient de Davies-Bouldin pour distance = 0.1 : 2.285910671956839
#  nb clusters =  4  , nb feuilles =  1000  runtime =  9.78  ms

# %%
lim_cluster(data,False)
# Out:
# Coefficient de silhouette pour k = 4 : 0.5054942636304086
# Coefficient de Davies-Bouldin pour k = 4 : 2.285910671956839
#  nb clusters =  4  , nb feuilles =  1000  runtime =  105.13  ms

# %% [markdown]
# #### 3.2 Intérêts  de la méthode

# %%
#choix des différents jeux de données

datab3 = arff.loadarff(open(path+"2d-4c.arff",'r'))
data3 = [[x[0],x[1]] for x in datab3[0]]
f2 = [f[0] for f in data3]
f3 = [f[1] for f in data3]

datab4 = arff.loadarff(open(path+"hepta.arff",'r'))
data4 = [[x[0],x[1]] for x in datab4[0]]
f4 = [f[0] for f in data4]
f5 = [f[1] for f in data4]

# %%
def set_distance(data,f0,f1, distance, plot=False):
    # set distance_threshold ( 0 ensures we compute the full tree )
    tps1 = time.time()
    model = cluster.AgglomerativeClustering(distance_threshold = distance , linkage = 'single' , n_clusters = None)
    model = model.fit(data)
    tps2 = time.time()
    labels = model.labels_
    k = model.n_clusters_
    leaves = model.n_leaves_
    
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
    print("Coefficient de silhouette pour distance =",distance,":",metrics.silhouette_score(data,labels))
    print("Coefficient de Davies-Bouldin pour distance =",distance,":",metrics.davies_bouldin_score(data,labels))
    print(" nb clusters = ",k," , nb feuilles = ",leaves, " runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms" , "for a distance of :", distance)
    print("\n")
for i in range (1,10,1):
    if(i == 5): set_distance(data3,f2,f3,i/1,True)
    else : set_distance(data3,f2,f3,i/1)
# Out:
# Coefficient de silhouette pour distance = 1.0 : 0.26038587511809475
# Coefficient de Davies-Bouldin pour distance = 1.0 : 0.4564233921037186
#  nb clusters =  40  , nb feuilles =  1261  runtime =  12.93  ms for a distance of : 1.0
#
#
# Coefficient de silhouette pour distance = 2.0 : 0.5897366488389997
# Coefficient de Davies-Bouldin pour distance = 2.0 : 0.3406551277413671
#  nb clusters =  13  , nb feuilles =  1261  runtime =  11.73  ms for a distance of : 2.0
#
#
# Coefficient de silhouette pour distance = 3.0 : 0.733543617356593
# Coefficient de Davies-Bouldin pour distance = 3.0 : 0.22624236333424383
#  nb clusters =  6  , nb feuilles =  1261  runtime =  96.42  ms for a distance of : 3.0
#
#
# Coefficient de silhouette pour distance = 4.0 : 0.733543617356593
# Coefficient de Davies-Bouldin pour distance = 4.0 : 0.22624236333424383
#  nb clusters =  6  , nb feuilles =  1261  runtime =  11.86  ms for a distance of : 4.0
# ...

# %% [markdown]
# - Pour le premier dataset qui a été choisi nour remarquons que les métriques d'évaluations fluctuent grandement. L'indice de Davies-Bouldin reste relativement faible. La meilleure des distances qui nous est proposée est donc 5.0

# %%
# Pour le second dataset nous avons :
for i in range (1,10,1):
    if(i == 6): set_distance(data4,f4,f5,i/10,True)
    else : set_distance(data4,f4,f5,i/10)
# Out:
# Coefficient de silhouette pour distance = 0.1 : 0.27093385825851224
# Coefficient de Davies-Bouldin pour distance = 0.1 : 0.1365866467040231
#  nb clusters =  143  , nb feuilles =  212  runtime =  2.07  ms for a distance of : 0.1
#
#
# Coefficient de silhouette pour distance = 0.2 : 0.31589182343879096
# Coefficient de Davies-Bouldin pour distance = 0.2 : 0.3955832736177741
#  nb clusters =  69  , nb feuilles =  212  runtime =  1.48  ms for a distance of : 0.2
#
#
# Coefficient de silhouette pour distance = 0.3 : 0.31235083230703253
# Coefficient de Davies-Bouldin pour distance = 0.3 : 0.579576461907027
#  nb clusters =  25  , nb feuilles =  212  runtime =  3.02  ms for a distance of : 0.3
#
#
# Coefficient de silhouette pour distance = 0.4 : 0.4642255131684581
# Coefficient de Davies-Bouldin pour distance = 0.4 : 0.660439598638908
#  nb clusters =  10  , nb feuilles =  212  runtime =  87.05  ms for a distance of : 0.4
#
#
# ...

# %% [markdown]
# - La distance pour laquelle nous avons des coefficients de silhouette et de Davies-Boudin les plus optimisés dans ce cas est 0.6

# %% [markdown]
# - Pour les distances actuelles nous allons voir les differentes manières de combiner des clusters.

# %%
def set_linkage(data,f0,f1, distance, link, plot=False):
    # set distance_threshold ( 0 ensures we compute the full tree )
    tps1 = time.time()
    model = cluster.AgglomerativeClustering(distance_threshold = distance , linkage = link , n_clusters = None)
    model = model.fit(data)
    tps2 = time.time()
    labels = model.labels_
    k = model.n_clusters_
    leaves = model.n_leaves_
    
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
    print("Pour le linkage :", link)
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("nb clusters = ",k,", nb feuilles = ",leaves, ", distance = ",distance, " , runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms ")
    print("\n")
    
def set_linkage2(data,f0,f1, nb_clusters, link, plot=False):
    #set the number of clusters 
    k = nb_clusters
    tps1 = time.time()
    model = cluster.AgglomerativeClustering(linkage = link , n_clusters = k)
    model = model.fit(data)
    tps2 = time.time()
    
    labels = model.labels_
    k = model.n_clusters_
    leaves = model.n_leaves_
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
        
    print("Pour le linkage :", link)
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("nb clusters = ",k," , nb feuilles = ",leaves, " runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms ")
    print("\n")

# %%
#Pour le premier dataset que nous avons choisi :
print("AVERAGE :\n")
for i in range (9,13,1):
    set_linkage(data3,f2,f3,i/1,'average')
print("\nCOMPLETE :\n")
for i in range (27,32,1):
    set_linkage(data3,f2,f3,i/1,'complete')
print("\nWARD :\n")
for i in range (96,99,1):
    set_linkage(data3,f2,f3,i/1,'ward')
# Out:
# AVERAGE :
#
# Pour le linkage : average
# Silhouette : 0.6792722924016678
# Davies-Bouldin : 0.4077233712338347
# nb clusters =  6 , nb feuilles =  1261 , distance =  9.0  , runtime =  27.43  ms
#
#
# Pour le linkage : average
# Silhouette : 0.6792722924016678
# Davies-Bouldin : 0.4077233712338347
# nb clusters =  6 , nb feuilles =  1261 , distance =  10.0  , runtime =  23.71  ms
#
#
# Pour le linkage : average
# Silhouette : 0.756513599513819
# Davies-Bouldin : 0.30878610238534987
# nb clusters =  5 , nb feuilles =  1261 , distance =  11.0  , runtime =  108.59  ms
#
#
# Pour le linkage : average
# Silhouette : 0.756513599513819
# Davies-Bouldin : 0.30878610238534987
# nb clusters =  5 , nb feuilles =  1261 , distance =  12.0  , runtime =  23.78  ms
#
#
#
# COMPLETE :
#
# Pour le linkage : complete
# Silhouette : 0.6710321765035772
# Davies-Bouldin : 0.6073635545627485
# nb clusters =  5 , nb feuilles =  1261 , distance =  27.0  , runtime =  23.51  ms
#
#
# ...

# %%
set_linkage(data3,f2,f3,5.0,'single',True)
set_linkage(data3,f2,f3,11.0,'average',True)
set_linkage(data3,f2,f3,29.0,'complete',True)
set_linkage(data3,f2,f3,98.0,'ward',True)
# Out:
# Pour le linkage : single
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.1655901866537172
# nb clusters =  4 , nb feuilles =  1261 , distance =  5.0  , runtime =  12.27  ms
# Pour le linkage : average
# Silhouette : 0.756513599513819
# Davies-Bouldin : 0.30878610238534987
# nb clusters =  5 , nb feuilles =  1261 , distance =  11.0  , runtime =  23.33  ms
# Pour le linkage : complete
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
# nb clusters =  4 , nb feuilles =  1261 , distance =  29.0  , runtime =  23.54  ms
# Pour le linkage : ward
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
# nb clusters =  4 , nb feuilles =  1261 , distance =  98.0  , runtime =  27.96  ms

# %% [markdown]
# - Le meilleur linkage pour le premier dataset reste le single dans ce cas, car il nous a demander le moins d'iteration pour trouver la distance mais aussi car il est le plus rapide pour un meme resultat.

# %%
#Pour le second dataset que nous avons choisi :
print("AVERAGE :\n")
for i in range (9,12,1):
    set_linkage(data4,f2,f3,i/10,'average')
print("\nCOMPLETE :\n")
for i in range (17,22,1):
    set_linkage(data4,f2,f3,i/10,'complete')
print("\nWARD :\n")
for i in range (41,44,1):
    set_linkage(data4,f2,f3,i/10,'ward')
# Out:
# AVERAGE :
#
# Pour le linkage : average
# Silhouette : 0.4314247139747543
# Davies-Bouldin : 0.7863158331242787
# nb clusters =  12 , nb feuilles =  212 , distance =  0.9  , runtime =  2.63  ms
#
#
# Pour le linkage : average
# Silhouette : 0.5309238500183187
# Davies-Bouldin : 0.8721334438832584
# nb clusters =  9 , nb feuilles =  212 , distance =  1.0  , runtime =  2.17  ms
#
#
# Pour le linkage : average
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
# nb clusters =  5 , nb feuilles =  212 , distance =  1.1  , runtime =  90.38  ms
#
#
#
# COMPLETE :
#
# Pour le linkage : complete
# Silhouette : 0.4285209494812307
# Davies-Bouldin : 0.8658475847573465
# nb clusters =  10 , nb feuilles =  212 , distance =  1.7  , runtime =  2.88  ms
#
#
# Pour le linkage : complete
# Silhouette : 0.42735201692979663
# Davies-Bouldin : 0.8769226052642171
# nb clusters =  9 , nb feuilles =  212 , distance =  1.8  , runtime =  3.32  ms
#
#
# Pour le linkage : complete
# ...

# %%
set_linkage(data4,f4,f5,0.6,'single',True)
set_linkage(data4,f4,f5,1.1,'average',True)
set_linkage(data4,f4,f5,2.0,'complete',True)
set_linkage(data4,f4,f5,4.3,'ward',True)
# Out:
# Pour le linkage : single
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.332136719624502
# nb clusters =  5 , nb feuilles =  212 , distance =  0.6  , runtime =  2.2  ms
# Pour le linkage : average
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
# nb clusters =  5 , nb feuilles =  212 , distance =  1.1  , runtime =  1.41  ms
# Pour le linkage : complete
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.332136719624502
# nb clusters =  5 , nb feuilles =  212 , distance =  2.0  , runtime =  1.47  ms
# Pour le linkage : ward
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.332136719624502
# nb clusters =  5 , nb feuilles =  212 , distance =  4.3  , runtime =  1.53  ms

# %% [markdown]
# - Dans ce cas la, le linkage single reste toujours celui le plus optimal car le plus simple a retrouver, cependant toutes les methodes arrivent a la solution de maniere rapide, elles se valent donc toutes.

# %% [markdown]
# - Les différentes valeurs de temps d'execution sont pour le premier dataset :
#     * single : 7.0 ms
#     * average : 18.0 ms
#     * complete : 18.01 ms
#     * ward : 21.0 ms
#
# donc même concernant la valeur du runtime le single est meilleur
#
# - Pour le second dataset nous avons :
#     * single : 0.98 ms
#     * average : 2.0 ms
#     * complete : 1.0 ms
#     * ward : 2.12 ms
#
# Cela reste donc la même chose dans ce cas la aussi.
#
# - Nous n'avons pas de critères attendus mais les valeurs que nous semblons obtenir sont cohérentes.

# %%
# Changement de la valeur du nombre de clusters. 
def set_nb_clusters(data,f0,f1, nb_clusters, plot=False):
    #set the number of clusters 
    k = nb_clusters
    tps1 = time.time()
    model = cluster.AgglomerativeClustering(linkage = 'single' , n_clusters = k)
    model = model.fit(data)
    tps2 = time.time()
    
    labels = model.labels_
    k = model.n_clusters_
    leaves = model.n_leaves_
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering ")
        plt.show()
        
    print("Nb clusters = ",k," , nb feuilles = ",leaves, " runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms " )
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("\n")

# %% [markdown]
# - Sur les mêmes dataset nous allons faire varier le nombre de clusters pour voir celui qui correspond le plus et qui nous apporte des valeurs de coefficient de silhouette et de coefficient de Davies-Bouldin les plus hauts.

# %%
# Pour le premier dataset nous avons donc :

for i in range(2,10,1):
    set_nb_clusters(data3,f2,f3,i)

set_nb_clusters(data3,f2,f3,4,True)
# Out:
# Nb clusters =  2  , nb feuilles =  1261  runtime =  192.95  ms
# Silhouette : 0.5601242918785256
# Davies-Bouldin : 0.484019057857106
#
#
# Nb clusters =  3  , nb feuilles =  1261  runtime =  100.28  ms
# Silhouette : 0.8663200072095998
# Davies-Bouldin : 0.18774183239134024
#
#
# Nb clusters =  4  , nb feuilles =  1261  runtime =  12.31  ms
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.1655901866537172
#
#
# Nb clusters =  5  , nb feuilles =  1261  runtime =  100.48  ms
# Silhouette : 0.782507022083732
# Davies-Bouldin : 0.20846713351581111
#
#
# Nb clusters =  6  , nb feuilles =  1261  runtime =  104.95  ms
# Silhouette : 0.733543617356593
# Davies-Bouldin : 0.22624236333424383
#
#
# Nb clusters =  7  , nb feuilles =  1261  runtime =  98.13  ms
# Silhouette : 0.6900192675717587
# Davies-Bouldin : 0.2649550025737205
#
#
# Nb clusters =  8  , nb feuilles =  1261  runtime =  17.35  ms
# Silhouette : 0.6407644223435996
# Davies-Bouldin : 0.30625383161695585
#
#
# ...

# %% [markdown]
# - Dans le cas de ce dataset le nombre de cluster qui semble le plus approprié semble être 4.

# %%
#Cas du second dataset utilisé:
for i in range(2,10,1):
    set_nb_clusters(data4,f4,f5,i)
    
set_nb_clusters(data4,f4,f5,5,True)
# Out:
# Nb clusters =  2  , nb feuilles =  212  runtime =  1.77  ms
# Silhouette : 0.4043535269540261
# Davies-Bouldin : 0.6801950836758982
#
#
# Nb clusters =  3  , nb feuilles =  212  runtime =  1.1  ms
# Silhouette : 0.4556933431481986
# Davies-Bouldin : 0.6867332087980328
#
#
# Nb clusters =  4  , nb feuilles =  212  runtime =  1.05  ms
# Silhouette : 0.6099830024411593
# Davies-Bouldin : 0.5557927403243392
#
#
# Nb clusters =  5  , nb feuilles =  212  runtime =  1.05  ms
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.332136719624502
#
#
# Nb clusters =  6  , nb feuilles =  212  runtime =  1.09  ms
# Silhouette : 0.6893164135989908
# Davies-Bouldin : 0.4775502497534711
#
#
# Nb clusters =  7  , nb feuilles =  212  runtime =  1.04  ms
# Silhouette : 0.618435259301357
# Davies-Bouldin : 0.518101778007744
#
#
# Nb clusters =  8  , nb feuilles =  212  runtime =  1.05  ms
# Silhouette : 0.5550517635833936
# Davies-Bouldin : 0.7189289686985916
#
#
# ...

# %% [markdown]
# - Dans le cas de ce dataset, ce qui semble convenir le plus semble être un nombre de clusters qui est égal à 5.

# %% [markdown]
# #### 3.3 Limites de la méthode

# %%
#On choisit deux dataset qui ne semblent pas fonctionner avec la méthode de clustering agglomeratif : 

#Premier Dataset:

datab5 = arff.loadarff(open(path+"dpb.arff",'r'))
data5 = [[x[0],x[1]] for x in datab5[0]]
f6 = [f[0] for f in data5]
f7 = [f[1] for f in data5]

plt.scatter(f6,f7,s=8)
plt.title("Donnees initiales")
plt.show()

#Second Dataset:

datab6 = arff.loadarff(open(path+"cluto-t7-10k.arff",'r'))
data6 = [[x[0],x[1]] for x in datab6[0]]
f8 = [f[0] for f in data6]
f9 = [f[1] for f in data6]

plt.scatter(f8,f9,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# - On peux essayer de déterminer une distance permettant d'avoir un clustering qui pourrait aller en reprenant la fonction `set_distance`

# %%
#Pour le premier dataset :

for i in range(1,5,1):
    set_distance(data5,f6,f7,i/100)
# Out:
# Coefficient de silhouette pour distance = 0.01 : -0.2681503663970448
# Coefficient de Davies-Bouldin pour distance = 0.01 : 0.4649495716091947
#  nb clusters =  834  , nb feuilles =  4000  runtime =  99.41  ms for a distance of : 0.01
#
#
# Coefficient de silhouette pour distance = 0.02 : -0.4593318668093466
# Coefficient de Davies-Bouldin pour distance = 0.02 : 0.7056903490484839
#  nb clusters =  285  , nb feuilles =  4000  runtime =  283.3  ms for a distance of : 0.02
#
#
# Coefficient de silhouette pour distance = 0.03 : -0.5309747935830144
# Coefficient de Davies-Bouldin pour distance = 0.03 : 0.5859650447068756
#  nb clusters =  68  , nb feuilles =  4000  runtime =  293.11  ms for a distance of : 0.03
#
#
# Coefficient de silhouette pour distance = 0.04 : -0.12297186602972307
# Coefficient de Davies-Bouldin pour distance = 0.04 : 0.47227312003095745
#  nb clusters =  15  , nb feuilles =  4000  runtime =  95.41  ms for a distance of : 0.04

# %%
#Pour le second dataset nous avons : 
for i in range(1,25,5):
    set_distance(data6,f8,f9,i)
set_distance(data6,f8,f9,6,True)
set_distance(data6,f8,f9,21,True)
# Out:
# Coefficient de silhouette pour distance = 1 : 0.11418152282325277
# Coefficient de Davies-Bouldin pour distance = 1 : 0.08009013658652403
#  nb clusters =  9085  , nb feuilles =  10000  runtime =  794.35  ms for a distance of : 1
#
#
# Coefficient de silhouette pour distance = 6 : -0.6669976223257734
# Coefficient de Davies-Bouldin pour distance = 6 : 1.357614878613133
#  nb clusters =  554  , nb feuilles =  10000  runtime =  781.32  ms for a distance of : 6
#
#
# Coefficient de silhouette pour distance = 11 : -0.8085881373061962
# Coefficient de Davies-Bouldin pour distance = 11 : 1.189798831884358
#  nb clusters =  160  , nb feuilles =  10000  runtime =  1009.92  ms for a distance of : 11
#
#
# Coefficient de silhouette pour distance = 16 : -0.7256663122004132
# Coefficient de Davies-Bouldin pour distance = 16 : 1.407780655151346
#  nb clusters =  28  , nb feuilles =  10000  runtime =  961.22  ms for a distance of : 16
#
#
# ...

# %% [markdown]
# - Comme nous pouvons le voir au niveau des valeurs, les coefficients sont exécrables et cela est lié au fait que les clustering sont difficiles à différencier sur les deux datasets qui sont donnés. Dans ce cas la il est difficile d'établir une distance qui permettrait de satisfaire les contraintes d'un bon clustering

# %% [markdown]
# #### 3.4 Comparaison des méthodes de clustering

# %% [markdown]
# - Pour établir une comparaion entre les différentes méthodes nous allons lancer celles-ci sur un dataset bien connu qui est le premier à avoir été introduit lors de ce TP :

# %%
# Nous avons donc le dataset suivant : 
databrut = arff.loadarff(open(path+"xclara.arff", 'r'))
data = [[x[0],x[1]] for x in databrut[0]]

#Affichage 2D
f0 = [f[0] for f in data]
f1 = [f[1] for f in data]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# - On applique donc toutes les méthodes que nous avons pour une valeur de clusters qui est de 3 comme nous avons déjà établi que celle-ci semblait être la plus optimale.

# %%
# On commence par la méthode K-means : 
k_means(data, f0,f1,3,True)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 3 : 0.6945587736089913
# Coefficient de Davies-Bouldin pour k = 3 : 0.42056158508478453
# nv clusters = 3 , nb iter = 3 , ...... runtime =  1916.56 ms

# %%
#Ensuite nous avons la méthode K-medoids
k_medoids(data, f0,f1,3)
# Out:
# Loss with FasterPAM: 38029.6560504377
# Coefficient de silhouette pour k = 3 : 0.6945587736089913
# Coefficient de Davies-Bouldin pour k = 3 : 0.42056158508478453
#  nb clusters = 3 , nb_iter = 2 , ...... runtime = 10236.1 ms

# %%
#Finalement la méthode de clustering agglomeratif avec un nombre de clusters qui est égal à 3 :
set_nb_clusters(data,f0,f1,3,True)
# Out:
# Nb clusters =  3  , nb feuilles =  3000  runtime =  55.57  ms
# Silhouette : 0.02996091241427347
# Davies-Bouldin : 0.6174199326691526

# %% [markdown]
# - Comme nous pouvons le voir, la méthode de clustering agglomeratif n'est pas une bone solution. Cette méthode fourni des valeurs de coefficient mauvaises donc il est préférable lorsque cela ne vaut pas le coup de se focaliser sur les autres méthodes. Les méthodes k-medoids et K-means étant tres approchée, elles fournissent des résultats trés proches l'une de l'autre. La différence se fait sentir au niveau du temps d'exécution qui est considérablement plus élevé pour K-medoids que pour K-means.

# %% [markdown]
# ### 4. Clustering DBSCAN et HDBSCAN

# %% [markdown]
# #### 4.1 Intérêts de la méthode DBSCAN

# %% [markdown]
# - Pour cette partie nous allons utiliser pour dataset le dataset 3, ainsi que le dataset numéro 4 qui sont des clusters assez isolés donc facilement traitables

# %%
def DBSCAN(data,f0,f1,plot = False):  
    tps1 = time.time()
    model = cluster.DBSCAN(eps=1,min_samples= 2)
    model = model.fit(data)
    tps2 = time.time()
    
    
    labels = model.labels_
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering DBSCAN")
        plt.show()
    
    print("runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms " )
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("\n")

# %%
DBSCAN(data3,f2,f3,True)
DBSCAN(data4,f4,f5,True)
# Out:
# runtime =  7.22  ms
# Silhouette : 0.5011856201728122
# Davies-Bouldin : 2.390910842092135
# runtime =  1.89  ms
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019

# %% [markdown]
# - Ici pour DBSCAN on initialise des valeurs qui sont aléatoires. Nous allos tout d'abord commencer par faire varier epsilon et ensuite nous vrrons les modifications

# %%
def DBSCAN_epsilon(data,f0,f1,epsilon,plot=False):
    tps1 = time.time()
    model = cluster.DBSCAN(eps=epsilon,min_samples= 2)
    model = model.fit(data)
    tps2 = time.time()
    
    
    labels = model.labels_
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering DBSCAN")
        plt.show()
    
    print("runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms pour un epsilon égal à ", epsilon )
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("\n")

# %%
for i in range(1,7,1):
    DBSCAN_epsilon(data3,f2,f3,i)
    
DBSCAN_epsilon(data3,f2,f3,5,True)
# Out:
# runtime =  94.2  ms pour un epsilon égal à  1
# Silhouette : 0.5011856201728122
# Davies-Bouldin : 2.390910842092135
#
#
# runtime =  7.88  ms pour un epsilon égal à  2
# Silhouette : 0.7625530466649794
# Davies-Bouldin : 3.6821782851644413
#
#
# runtime =  8.18  ms pour un epsilon égal à  3
# Silhouette : 0.7982383043497796
# Davies-Bouldin : 3.3094878518458257
#
#
# runtime =  8.95  ms pour un epsilon égal à  4
# Silhouette : 0.7982383043497796
# Davies-Bouldin : 3.3094878518458257
#
#
# runtime =  98.3  ms pour un epsilon égal à  5
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  10.16  ms pour un epsilon égal à  6
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
# runtime =  9.34  ms pour un epsilon égal à  5
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716

# %% [markdown]
# - le resultat permettant d'avoir des valeurs qui semblent correctes pour les coefficient à une valeur de epsilon de 5. Nous allons maintenant essayer de voir si nous pouvons affiner ce résultat en faisant varier min_samples.

# %%
def DBSCAN_samples(data,f0,f1,samples,epsilon=5,plot=False):
    tps1 = time.time()
    model = cluster.DBSCAN(eps=epsilon,min_samples= samples)
    model = model.fit(data)
    tps2 = time.time()
    
    
    labels = model.labels_
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = labels,s = 8 )
        plt.title(" Resultat du clustering DBSCAN")
        plt.show()
    
    print("runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms pour une valeur de min_samples égale à ", samples )
    print("Silhouette :",metrics.silhouette_score(data,labels))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,labels))
    print("\n")

# %%
for i in range(1,7):
    DBSCAN_samples(data3,f2,f3,i)
DBSCAN_samples(data3,f2,f3,1,plot=True)
# Out:
# runtime =  10.05  ms pour une valeur de min_samples égale à  1
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  9.67  ms pour une valeur de min_samples égale à  2
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  186.07  ms pour une valeur de min_samples égale à  3
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  98.42  ms pour une valeur de min_samples égale à  4
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  10.54  ms pour une valeur de min_samples égale à  5
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  9.4  ms pour une valeur de min_samples égale à  6
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
# runtime =  16.57  ms pour une valeur de min_samples égale à  1
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716

# %% [markdown]
# - Dans notre cas, la valeur de min_sample qui fonctionne le mieux est 1.

# %% [markdown]
# - Nous allons suivre le même processus pour le deuxième dataset que nous avons décidé de traiter

# %%
for i in range(1,8,1):
    DBSCAN_epsilon(data4,f4,f5,i/10)
DBSCAN_epsilon(data4,f4,f5,0.6,True)
# Out:
# runtime =  2.0  ms pour un epsilon égal à  0.1
# Silhouette : -0.14624890248394756
# Davies-Bouldin : 5.818102439231554
#
#
# runtime =  2.21  ms pour un epsilon égal à  0.2
# Silhouette : 0.2628706618307262
# Davies-Bouldin : 1.6157118146602625
#
#
# runtime =  1.89  ms pour un epsilon égal à  0.3
# Silhouette : 0.37606092217399434
# Davies-Bouldin : 1.5276848099805755
#
#
# runtime =  4.57  ms pour un epsilon égal à  0.4
# Silhouette : 0.6121053117027413
# Davies-Bouldin : 0.8391002359640672
#
#
# runtime =  1.98  ms pour un epsilon égal à  0.5
# Silhouette : 0.6893164135989908
# Davies-Bouldin : 0.477550249753471
#
#
# runtime =  1.99  ms pour un epsilon égal à  0.6
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  2.12  ms pour un epsilon égal à  0.7
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
# runtime =  4.66  ms pour un epsilon égal à  0.6
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019

# %% [markdown]
# - La meilleure valeur de epsilon que l'on obtient dans ce cas est 0.6 maintenant intéressons nous a min_samples

# %%
for i in range(1,20):
    DBSCAN_samples(data4,f4,f5,i,0.6)
DBSCAN_samples(data4,f4,f5,1,0.6, True)
# Out:
# runtime =  1.99  ms pour une valeur de min_samples égale à  1
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  3.16  ms pour une valeur de min_samples égale à  2
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  1.99  ms pour une valeur de min_samples égale à  3
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  91.24  ms pour une valeur de min_samples égale à  4
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  1.99  ms pour une valeur de min_samples égale à  5
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  1.99  ms pour une valeur de min_samples égale à  6
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# runtime =  90.56  ms pour une valeur de min_samples égale à  7
# Silhouette : 0.738310401247651
# Davies-Bouldin : 0.3321367196245019
#
#
# ...

# %% [markdown]
# - les valeurs pour les coefficient semblent diminuer lorsque l'on augmente la valeur de min_sample donc en s'en tenant à 1 cela fonctionne.

# %% [markdown]
# #### 4.2 Limites de la méthode DBSCAN

# %%
#Nous choisissons des datasets pour lesquels on ne risque pas d'avoir de problèmes donc le suivant : 

#Premier Dataset:

datab8 = arff.loadarff(open(path+"disk-6000n.arff",'r'))
data8 = [[x[0],x[1]] for x in datab8[0]]
f10 = [f[0] for f in data8]
f11 = [f[1] for f in data8]

plt.scatter(f10,f11,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# - nous allons donc vérifier pour la recherche de epsilon :

# %%
for i in range(1,5,1):
    DBSCAN_epsilon(data8,f10,f11,i/10)
DBSCAN_epsilon(data8,f10,f11,0.4,True)
# Out:
# runtime =  25.32  ms pour un epsilon égal à  0.1
# Silhouette : -0.20959450255175857
# Davies-Bouldin : 1.2550126613722627
#
#
# runtime =  123.05  ms pour un epsilon égal à  0.2
# Silhouette : 0.17245568265642236
# Davies-Bouldin : 1.3461241408549394
#
#
# runtime =  213.16  ms pour un epsilon égal à  0.3
# Silhouette : -0.7405131517162448
# Davies-Bouldin : 3.391393609943007
#
#
# runtime =  30.78  ms pour un epsilon égal à  0.4
# Silhouette : -0.06327925899633323
# Davies-Bouldin : 130.1673377929796
# runtime =  30.54  ms pour un epsilon égal à  0.4
# Silhouette : -0.06327925899633323
# Davies-Bouldin : 130.1673377929796

# %% [markdown]
# - les valeurs obtenues pour la densité sont tres faibles et on ne semble pas avoir de valeurs qui satisfasse les nécessitées pour avoir un bon clustering.

# %% [markdown]
# #### 4.3 Comparaison avec la méthode HDBSCAN

# %%
def HDBSCAN(data,f0,f1,sample, plot=False):
    
    tps1 = time.time()
    model = hdbscan.HDBSCAN(min_cluster_size=sample)
    model_label = model.fit_predict(data)
    tps2 = time.time()
    
    # Affichage clustering
    if(plot):
        plt.scatter(f0,f1,c = model_label,s = 8 )
        plt.title(" Resultat du clustering HDBSCAN")
        plt.show()
    
    print("runtime = " ,round((tps2 - tps1) * 1000 , 2 ) ," ms pour min_sample de",sample )
    print("Silhouette :",metrics.silhouette_score(data,model_label))
    print("Davies-Bouldin :",metrics.davies_bouldin_score(data,model_label))
    print("\n")

# %% [markdown]
# - Nous allons tester le même dataset que pour dbscan avec une modification de min samples.

# %%
for i in range(2,7,1):
    HDBSCAN(data3,f2,f3,i)
HDBSCAN(data3,f2,f3,4,True)
# Out:
# runtime =  36.01  ms pour min_sample de 2
# Silhouette : 0.1518820387725206
# Davies-Bouldin : 1.0784862715396846
#
#
# runtime =  209.09  ms pour min_sample de 3
# Silhouette : 0.5270870714781966
# Davies-Bouldin : 4.086448380855486
#
#
# runtime =  23.52  ms pour min_sample de 4
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  113.38  ms pour min_sample de 5
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
#
#
# runtime =  107.17  ms pour min_sample de 6
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716
# runtime =  113.49  ms pour min_sample de 4
# Silhouette : 0.8670311065845322
# Davies-Bouldin : 0.16559018665371716

# %% [markdown]
# - Pour le premier dataset, on retrouve pour une valeur de min_cluster de 4 des valeurs qui sont cohérentes avec DBSCAN
# - le Dataset sur lequel nous voyons des améliorations peut être le dataset numéro trois qui est le suivant :

# %%
for i in range(4,8,1):
        DBSCAN_epsilon(data6,f8,f9,i)
DBSCAN_epsilon(data6,f8,f9,7,True)
# Out:
# runtime =  51.29  ms pour un epsilon égal à  4
# Silhouette : 0.025097445336906877
# Davies-Bouldin : 1.3432509772113066
#
#
# runtime =  236.1  ms pour un epsilon égal à  5
# Silhouette : -0.4412363289871505
# Davies-Bouldin : 1.586108763004148
#
#
# runtime =  271.14  ms pour un epsilon égal à  6
# Silhouette : -0.6138598127633591
# Davies-Bouldin : 2.2247081662931354
#
#
# runtime =  313.95  ms pour un epsilon égal à  7
# Silhouette : -0.6278342024368824
# Davies-Bouldin : 2.3404223494936662
# runtime =  277.07  ms pour un epsilon égal à  7
# Silhouette : -0.6278342024368824
# Davies-Bouldin : 2.3404223494936662

# %%
HDBSCAN(data6,f8,f9,200,True)
# Out:
# runtime =  663.38  ms pour min_sample de 200
# Silhouette : 0.17459684935280345
# Davies-Bouldin : 2.8350156290344457

# %% [markdown]
# - Comme nous pouvons le voir une légère amélioration du coefficient de silhouette se perçoit sur la méthode HDBSCAN du fait de la hiérarchisation.

# %% [markdown]
# ### 5. Evaluation

# %% [markdown]
# - Dans cette artie nous allons appliquer les différentes méthodes que nous avons étudiés pour les différents datasets qui sont proposés. ( Dans un soucis fonctionnel nous laisserons le dataset y1 de côté).
# - Les analyses des différentes méthodes seront données dans le rapport.

# %% [markdown]
# #### 5.1 Premier Dataset

# %%
path = './dataset-rapport/'
filename = 'x1.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.1.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 2 : 0.3921445674558804
# Coefficient de Davies-Bouldin pour k = 2 : 1.1076795951090395
# nv clusters = 2 , nb iter = 6 , ...... runtime =  1940.66 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 3 : 0.4154382152214585
# Coefficient de Davies-Bouldin pour k = 3 : 0.8491798182688267
# nv clusters = 3 , nb iter = 6 , ...... runtime =  2141.58 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 4 : 0.4452742493111422
# Coefficient de Davies-Bouldin pour k = 4 : 0.7811089844899578
# nv clusters = 4 , nb iter = 6 , ...... runtime =  1728.73 ms
#
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 5 : 0.46397149871678955
# Coefficient de Davies-Bouldin pour k = 5 : 0.7443529104001547
# nv clusters = 5 , nb iter = 19 , ...... runtime =  2178.33 ms
#
# Appel KMeans pour une valeur fixee de k
# ...

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 15. Vérifions pour les autres méthodes.

# %%
k_means(datanp,f0,f1,15,True)
# Out:
# Appel KMeans pour une valeur fixee de k
# Coefficient de silhouette pour k = 15 : 0.711332992937958
# Coefficient de Davies-Bouldin pour k = 15 : 0.36641025866204857
# nv clusters = 15 , nb iter = 3 , ...... runtime =  1921.24 ms

# %% [markdown]
# ##### 5.1.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)
# Out:
# Loss with FasterPAM: 1202705593.580066
# Coefficient de silhouette pour k = 2 : 0.3854941605895685
# Coefficient de Davies-Bouldin pour k = 2 : 1.112895138391985
#  nb clusters = 2 , nb_iter = 2 , ...... runtime = 14008.22 ms
#
# Loss with FasterPAM: 966166751.9379776
# Coefficient de silhouette pour k = 3 : 0.4150772475615044
# Coefficient de Davies-Bouldin pour k = 3 : 0.8499904226513472
#  nb clusters = 3 , nb_iter = 3 , ...... runtime = 22961.52 ms

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,15)

# %% [markdown]
# ##### 5.1.3 Méthode de clustering agglomératif

# %% [markdown]
# - Dans le cas du clustering agglomeratif nous allons nous baser sur la modification du nombre de cluster pour trouver celle qui fonctionne le mieux.

# %%
for i in range(2,20):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 8 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 8, 'single', plot=False)
set_linkage2(datanp,f0,f1, 8, 'average', plot=False)
set_linkage2(datanp,f0,f1, 8, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 8, 'ward', plot=False)

# %% [markdown]
# - Ainsi celui donnant les meilleurs résultats semble être le linkage ward.

# %% [markdown]
# ##### 5.1.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(18000,20000,100):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=True)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 19600. Finalement nous modificant la valeur de samples.

# %%
for i in range(1,10,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=19600,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur semble être de 7 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,7,epsilon=19600,plot=True)

# %% [markdown]
# ##### 5.1.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(2,20,1):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici la meilleure valeur semble être 16 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,16, plot=True)

# %% [markdown]
# #### 5.2 Second Dataset

# %%
path = './dataset-rapport/'
filename = 'x2.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.2.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 15. Vérifions pour les autres méthodes.

# %% [markdown]
# ##### 5.2.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,15)

# %% [markdown]
# ##### 5.2.3 Méthode de clustering agglomératif

# %%
for i in range(2,50):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 2 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 2, 'single', plot=False)
set_linkage2(datanp,f0,f1, 2, 'average', plot=False)
set_linkage2(datanp,f0,f1, 2, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 2, 'ward', plot=False)

# %% [markdown]
# - Ainsi celui donnant les meilleurs résultats semble être le linkage ward.

# %% [markdown]
# ##### 5.2.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(7000,8000,100):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=True)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 7900. Finalement nous modificant la valeur de samples.

# %%
for i in range(1,20,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=7900,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur semble être de 1 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,1,epsilon=7900,plot=True)

# %% [markdown]
# ##### 5.2.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(2,20,1):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici la meilleure valeur semble être 16 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,13, plot=True)

# %% [markdown]
# #### 5.3 Troisieme Dataset

# %%
path = './dataset-rapport/'
filename = 'x3.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.3.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 15. Vérifions pour les autres méthodes.

# %% [markdown]
# ##### 5.3.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,15)

# %% [markdown]
# ##### 5.3.3 Méthode de clustering agglomératif

# %%
for i in range(2,20):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 2 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 2, 'single', plot=False)
set_linkage2(datanp,f0,f1, 2, 'average', plot=False)
set_linkage2(datanp,f0,f1, 2, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 2, 'ward', plot=False)

# %% [markdown]
# - Ainsi celui donnant les meilleurs résultats semble être le linkage complete.

# %% [markdown]
# ##### 5.3.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(5000,9000,100):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=False)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 8300. Finalement nous modificant la valeur de samples.

# %%
for i in range(1,10,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=8300,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur semble être de 1 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,1,epsilon=8300,plot=True)

# %% [markdown]
# ##### 5.3.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(270,290,5):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici la meilleure valeur semble être 275 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,275, plot=True)

# %% [markdown]
# #### 5.4 Quatrieme Dataset

# %%
path = './dataset-rapport/'
filename = 'x4.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.4.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 15. Vérifions pour les autres méthodes.

# %% [markdown]
# ##### 5.4.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,15)

# %% [markdown]
# ##### 5.4.3 Méthode de clustering agglomératif

# %%
for i in range(2,20):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 2 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 2, 'single', plot=False)
set_linkage2(datanp,f0,f1, 2, 'average', plot=False)
set_linkage2(datanp,f0,f1, 2, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 2, 'ward', plot=False)

# %% [markdown]
# - Ainsi celui donnant les meilleurs résultats semble être le linkage single.

# %% [markdown]
# ##### 5.4.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(1000,10000,1000):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=True)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 7000 (ce qui semble assez bizarre ). Finalement nous modificant la valeur de samples.

# %%
for i in range(1,10,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=7000,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur semble être de 1 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,1,epsilon=7000,plot=True)

# %% [markdown]
# ##### 5.4.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(12,30,1):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici la meilleure valeur semble être 21 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,21, plot=True)

# %% [markdown]
# #### 5.5 Cinquième Dataset

# %%
path = './dataset-rapport/'
filename = 'zz1.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.5.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 8. Vérifions pour les autres méthodes.

# %% [markdown]
# ##### 5.5.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,8)

# %% [markdown]
# ##### 5.5.3 Méthode de clustering agglomératif

# %%
for i in range(2,20):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 14 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 14, 'single', plot=False)
set_linkage2(datanp,f0,f1, 14, 'average', plot=False)
set_linkage2(datanp,f0,f1, 14, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 14, 'ward', plot=False)

# %% [markdown]
# - Ainsi celui donnant les meilleurs résultats semble être le linkage single.

# %% [markdown]
# ##### 5.5.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(7000,14000,1000):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=True)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 8000. Finalement nous modificant la valeur de samples.

# %%
for i in range(1,10,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=8000,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur semble être de 6 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,6,epsilon=8000,plot=True)

# %% [markdown]
# ##### 5.5.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(2,20,1):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici la meilleure valeur semble être 5 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,5, plot=True)

# %% [markdown]
# #### 5.6 Sixième Dataset

# %%
path = './dataset-rapport/'
filename = 'zz2.txt'
databrut = pd.read_csv(path+filename, sep=" ", encoding = "ISO-8859-1", skipinitialspace=True)
data = databrut 
datanp = databrut.to_numpy()

#Affichage 2D
f0 = [f[0] for f in datanp]
f1 = [f[1] for f in datanp]

plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %% [markdown]
# ##### 5.6.1 Méthode K-means

# %%
for i in range(2,20):
    k_means(datanp,f0,f1,i)

# %% [markdown]
# - La meilleure valeur de cluster dans ce cas la est 2. Vérifions pour les autres méthodes.

# %% [markdown]
# ##### 5.6.2 Méthode K-Medoids

# %%
for i in range(2,20):
    k_medoids(datanp,f0,f1,i)

# %% [markdown]
# - Nous pouvons lancer une évaluation entre les deux méthodes étant donné que nous avons le même nombre de cluster pour voir les différences au niveau des deux méthodes :

# %%
evaluation(datanp,f0,f1,15)

# %% [markdown]
# ##### 5.6.3 Méthode de clustering agglomératif

# %%
for i in range(2,20):
    set_nb_clusters(datanp,f0,f1, i, plot=False)

# %% [markdown]
# - Dans ce cas la le nombre de cluster qui semble le plus approprié semble être 2 mais les valeurs sont plus faibles nous pouvons voir si cela s'améliore en modifiant le linkage

# %%
set_linkage2(datanp,f0,f1, 2, 'single', plot=False)
set_linkage2(datanp,f0,f1, 2, 'average', plot=False)
set_linkage2(datanp,f0,f1, 2, 'complete', plot=False)
set_linkage2(datanp,f0,f1, 2, 'ward', plot=False)

# %% [markdown]
# - Ici, tout les linkage nous donnent la même valeur donc le choix se base uniquement sur le runtime donc on choisit le linkage single.

# %% [markdown]
# ##### 5.6.4 Méthode DBSCAN

# %% [markdown]
# - Pour cette méthode on doit évaluer la valeur de epsilon et de min_samples pour lesquelles nous avons des bonnes valeurs

# %%
for i in range(10,700,10):
    DBSCAN_epsilon(datanp,f0,f1,i,plot=True)

# %% [markdown]
# - la meilleure valeur dans notre cas semble être 130. Finalement nous modificant la valeur de samples.

# %%
for i in range(1,10,1):
    DBSCAN_samples(datanp,f0,f1,i,epsilon=130,plot=False)

# %% [markdown]
# Dans ce cas la, la meilleure valeur donnée par le runtime car égales semble être de 6 nous avons donc :

# %%
DBSCAN_samples(datanp,f0,f1,6,epsilon=130,plot=True)

# %% [markdown]
# ##### 5.6.5 Méthode HDBSCAN

# %% [markdown]
# - Nous allons itérer pour essayer de trouver ce qui convient le mieux en terme de min_clust_size.

# %%
for i in range(2,20,1):
    HDBSCAN(datanp,f0,f1,i, plot=False)

# %% [markdown]
# - Ici, comme nous avons plusieurs valeurs égales nous allons considérer le runtime. la meilleure valeur semble être 11 donc nous avons :

# %%
HDBSCAN(datanp,f0,f1,11, plot=True)
